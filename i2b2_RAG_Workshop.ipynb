# %% [markdown]
# # RAG Tutorial for i2b2 Developers using CSV (No ChromaDB Required)
#
# This notebook demonstrates how Retrieval-Augmented Generation (RAG) works using just a CSV file with embedded vectors and patient notes — no ChromaDB required. It supports both OpenAI and a local model (Ollama/Qwen2) and simulates the Patient Data Object (PDO) pattern from i2b2.
#
# ---

# %%
## 1. Patient Picker + Contextual Summary

import pandas as pd
import ipywidgets as widgets
from IPython.display import display, Markdown

# Load consolidated table
df = pd.read_csv("consolidated_table.csv")

# Extract patient metadata
df["patient_num"] = df["patient_num"].astype(str)
patient_selector = widgets.Dropdown(
    options=sorted(df["patient_num"].unique()),
    description="Patient #:",
    layout=widgets.Layout(width='40%')
)

# Define asthma vs non-asthma classification
no_asthma_patient_nums = {
    "1000000002", "1000000003", "1000000009", "1000000010", "1000000013",
    "1000000023", "1000000036", "1000000040", "1000000047", "1000000048",
    "1000000052", "1000000063", "1000000064", "1000000068", "1000000071",
    "1000000082", "1000000086", "1000000087", "1000000093", "1000000101",
    "1000000103", "1000000107"
}

def has_asthma(patient_num):
    return patient_num not in no_asthma_patient_nums

summary_output = widgets.Output()

@widgets.interact(patient=patient_selector)
def update_summary(patient):
    summary_output.clear_output()
    patient_rows = df[df["patient_num"] == patient]
    if patient_rows.empty:
        return

    doc_row = patient_rows.iloc[0]
    document_text = eval(doc_row["metadata"])['chroma:document']
    asthma_status = "✅ Asthma" if has_asthma(patient) else "❌ No Asthma"

    with summary_output:
        display(Markdown(f"### Patient {patient} - {asthma_status}"))
        display(Markdown(f"**Date:** {doc_row['visit_date']}"))
        display(widgets.Textarea(value=document_text[:1500], layout=widgets.Layout(width='100%', height='300px')))
widgets.Label("Note Type Used: Provider Notes")
update_summary(patient_selector.value)
display(summary_output)
# Out:
# interactive(children=(Dropdown(description='Patient #:', layout=Layout(width='40%'), options=('1000000001', '1…
# Output()

# %%
df
# Out:
#     patient_num            timestamp collection_name          doc_id  \
# 0    1000000001  2025-04-29 18:22:34   my_collection  doc_1000000001
# 1    1000000001  2025-04-29 18:22:48   my_collection  doc_1000000001
# 2    1000000001  2025-04-29 18:23:00   my_collection  doc_1000000001
# 3    1000000001  2025-04-29 18:23:10   my_collection  doc_1000000001
# 4    1000000001  2025-04-29 18:23:30   my_collection  doc_1000000001
# 5    1000000001  2025-04-29 18:23:39   my_collection  doc_1000000001
# 6    1000000002  2025-04-29 18:23:49   my_collection  doc_1000000002
# 7    1000000002  2025-04-29 18:24:01   my_collection  doc_1000000002
# 8    1000000002  2025-04-29 18:24:15   my_collection  doc_1000000002
# 9    1000000002  2025-04-29 18:24:27   my_collection  doc_1000000002
# 10   1000000002  2025-04-29 18:24:40   my_collection  doc_1000000002
# 11   1000000002  2025-04-29 18:24:51   my_collection  doc_1000000002
# 12   1000000002  2025-04-29 18:25:00   my_collection  doc_1000000002
# 13   1000000002  2025-04-29 18:25:10   my_collection  doc_1000000002
# 14   1000000002  2025-04-29 18:25:22   my_collection  doc_1000000002
# 15   1000000002  2025-04-29 18:25:33   my_collection  doc_1000000002
# 16   1000000002  2025-04-29 18:25:42   my_collection  doc_1000000002
# 17   1000000002  2025-04-29 18:25:54   my_collection  doc_1000000002
# 18   1000000002  2025-04-29 18:26:04   my_collection  doc_1000000002
# 19   1000000003  2025-04-29 18:26:15   my_collection  doc_1000000003
# 20   1000000003  2025-04-29 18:26:22   my_collection  doc_1000000003
# 24  embedding_1000000003  0xEDECF43C9197BB3CC5DF703BACD58B3CE2A29D3C27C4...
# 25  embedding_1000000003  0x448CC63C437C043D6BDB903BD2119E3CCAE1803CE787...
# 26  embedding_1000000003  0x92A2A33C73D4DA3C619E9A3B5AD9A93C57476B3CF10B...
# 27  embedding_1000000003  0x07C8CD3CB567063D9994D73BD8B5623CA658D33C0EF6...
# 28  embedding_1000000003  0x20399A3C3BC8073D4F74C13B00659D3C7CACA63CB74B...
# 29  embedding_1000000003  0x32A27B3C26D4123DC8F6A03AF4C1953C2ED6A03CEAD6...
# 30  embedding_1000000003  0x0AAD933C3E83793CD0935D38A4CD0B3C237BF73CE2F5...
# 31  embedding_1000000003  0x0688743C470D093D2F7EBC3A510A733C7498163D0CBF...
# 32  embedding_1000000003  0xE6A7783CA33CA23CFECE1DBB68589E3C5D28FE3C4EC1...
# 33  embedding_1000000003  0x2EE8433CE2FCDF3C4AFD81BBFA16A83CC4F60F3D47D8...
# 34  embedding_1000000003  0x8F939E3CB814003DC6813EBAD7280C3CAD3C473C3B83...
#
#    embedding_format                                           metadata
# 0           FLOAT32  {"patient_num": "1000000001", "encounter_id": ...
# 1           FLOAT32  {"patient_num": "1000000001", "encounter_id": ...
# 2           FLOAT32  {"patient_num": "1000000001", "encounter_id": ...
# 3           FLOAT32  {"patient_num": "1000000001", "encounter_id": ...
# 4           FLOAT32  {"patient_num": "1000000001", "encounter_id": ...
# 5           FLOAT32  {"patient_num": "1000000001", "encounter_id": ...
# 6           FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 7           FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 8           FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 9           FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 10          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 11          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 12          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 13          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 14          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 15          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 16          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 17          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 18          FLOAT32  {"patient_num": "1000000002", "encounter_id": ...
# 19          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 20          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 21          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 22          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 23          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 24          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 25          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 26          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 27          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 28          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 29          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 30          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 31          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 32          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 33          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...
# 34          FLOAT32  {"patient_num": "1000000003", "encounter_id": ...

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI

load_dotenv()

# Set up Azure credentials and token provider
azure_credential = DefaultAzureCredential()
token_provider = get_bearer_token_provider(
    azure_credential, "https://cognitiveservices.azure.com/.default"
)

# Initialize the AzureChatOpenAI model using environment variables
model = AzureChatOpenAI(
    openai_api_version=os.getenv("AZURE_OPENAI_VERSION"),
    azure_deployment=os.getenv("AZURE_OPENAI_DEPLOYMENT"),
    azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"),
    azure_ad_token_provider=token_provider
)

# Initialize the AzureOpenAIEmbeddings model using environment variables
embedding_model = AzureOpenAIEmbeddings(
    model=os.getenv("AZURE_EMBEDDING_MODEL"),
    azure_deployment=os.getenv("AZURE_EMBEDDING_DEPLOYMENT"),
    api_version=os.getenv("AZURE_EMBEDDING_API_VERSION"),
    azure_endpoint=os.getenv("AZURE_EMBEDDING_ENDPOINT"),
    azure_ad_token_provider=token_provider,
    timeout=None,  # never timeout
    max_retries=2,  # try again twice
)

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import struct, binascii

# Function to convert HEX embedding to list of floats
def hex_to_vector(hex_str):
    hex_clean = hex_str[2:] if hex_str.startswith("0x") else hex_str
    return list(struct.unpack(f'{len(hex_clean)//8}f', binascii.unhexlify(hex_clean)))

# %%
# Build document vectors
vectors = df["embedding"].apply(hex_to_vector).tolist()
X = np.array(vectors)

# %%
# Embed a query
query = "Does the patient have asthma and take fluticasone?"
query_embedding = embedding_model.embed_query(query)

# %%
# Compute cosine similarity
similarities = cosine_similarity([query_embedding], X)[0]
df["similarity"] = similarities

# Filter top results
top_k = df[df["similarity"] > 0.45].sort_values(by="similarity", ascending=False).head(10)

# Show top retrieved chunks
for idx, row in top_k.iterrows():
    note = eval(row["metadata"])['chroma:document']
    print(f"Patient #{row['patient_num']} -  - Similarity: {row['similarity']:.2f}")
    print(note[:500], "...\n")
# Out:
# Patient #1000000001 -  - Similarity: 0.56
# This is a 23-year-old Black female who has been receiving care at our clinic for several months. She speaks English and presents today, March 4, 2008, for a follow-up appointment due to persistent asthma symptoms. The patient has been managing extrinsic asthma without status asthmaticus and recent episodes of dizziness and giddiness. Additionally, she has reported an irregular menstrual cycle and a history of unspecified gastritis and gastroduodenitis.
#
# **Subjective:**
# The patient reports ongoin ...
#
# Patient #1000000001 -  - Similarity: 0.55
# This is a 23-year-old Black female who has been receiving care at our clinic for several months. She speaks English and presents today, August 11, 2008, for a follow-up appointment due to persistent asthma symptoms. The patient has a primary diagnosis of asthma, unspecified without mention of status asthmaticus, and has also been managing extrinsic asthma without status asthmaticus. Additionally, she has reported recurring shortness of breath, dyspnea, chest pain, dizziness, irregular menstrual  ...
#
# Patient #1000000001 -  - Similarity: 0.55
# This is a 22-year-old Black female who has been receiving care at our clinic for several years. She communicates in English and presents today, March 29, 2007, for a follow-up visit. The patient has been managing chronic asthma, with previous diagnoses indicating episodes of asthma exacerbation as well as unspecified asthma without mention of status asthmaticus. Additionally, she has a history of hypotension and contact dermatitis. She has been taking Sulfamethoxazole-Trimethoprim solution inter ...
#
# Patient #1000000001 -  - Similarity: 0.55
# This is a 24-year-old Black female who has been receiving care at our clinic for several months. She speaks English and presents today, May 18, 2009, for a follow-up appointment due to persistent asthma symptoms. The patient has a primary diagnosis of cough variant asthma and has also been managing secondary diagnoses including esophageal reflux and cardiac dysrhythmia, unspecified. Additionally, she has reported issues with other and unspecified diseases of the oral soft tissues, unspecified sy ...
#
# Patient #1000000001 -  - Similarity: 0.54
# Visit Information:
#     - Patient ID: 1000000001
#     - Encounter ID: 480315
#     - Visit Date: 09/20/2007
#
# This is a 22-year-old Black female who has been receiving care at our clinic for several years. She communicates in English and presents today, September 20, 2007, for a follow-up visit due to worsening asthma symptoms. The patient has a history of chronic asthma, with both exacerbation and stable periods, and is currently experiencing an increase in symptoms unresponsive to her usual quick-r ...

# %%
rag_prompt = f"""
Context:

{top_k['metadata'].apply(lambda x: eval(x)['chroma:document'][:500]).str.cat(sep="\n\n")}

Question: Does the patient have asthma and are they taking fluticasone?
Answer:
"""
print(rag_prompt[:1000])
# Out:
# Context:
#
# This is a 23-year-old Black female who has been receiving care at our clinic for several months. She speaks English and presents today, March 4, 2008, for a follow-up appointment due to persistent asthma symptoms. The patient has been managing extrinsic asthma without status asthmaticus and recent episodes of dizziness and giddiness. Additionally, she has reported an irregular menstrual cycle and a history of unspecified gastritis and gastroduodenitis.
#
# **Subjective:**
# The patient reports ongoin
#
# This is a 23-year-old Black female who has been receiving care at our clinic for several months. She speaks English and presents today, August 11, 2008, for a follow-up appointment due to persistent asthma symptoms. The patient has a primary diagnosis of asthma, unspecified without mention of status asthmaticus, and has also been managing extrinsic asthma without status asthmaticus. Additionally, she has reported recurring shortness of breath, dyspnea, chest pain, dizziness, irregul

# %%
result = model.invoke(rag_prompt)
# result = ollama.invoke(rag_prompt)


print("\nResponse from LLM:\n")
print(result.content)
# Out:
# Response from LLM:
#
# Yes, the patient has asthma, as indicated by multiple follow-up visits for asthma management and the primary diagnosis of asthma without status asthmaticus. There is no specific mention of the patient taking fluticasone in the provided context.
